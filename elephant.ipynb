# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_1 = pd.read_stata("/content/drive/MyDrive/ELEPHANT/country.dta")

# %%
len(df_1.country.unique())
# Out:
# 76

# %%
df_1.country = df_1.country.astype('string')

# %%
df_1_country = list(df_1.country.unique())

# %%
patents_data = pd.read_csv("/content/drive/MyDrive/ELEPHANT/PATS_IPC_25102023222244840.csv") #https://stats.oecd.org/#

# %%
patents_data.head()
patents_data.Country = patents_data.Country.apply(lambda x: x.lower()).replace("china (people's republic of)","china")
patents_country = list(patents_data.Country.unique())

# %%
# Select only the columns you need
patents_df = patents_data[["Country", "Value", "Time", 'IPC', 'KINDDATE', 'KINDCOUNTRY', 'Patents Office & Patents Families']]

# Filter the data based on conditions
new_pat = patents_df[(patents_df['IPC'] == "ENV_TECH") &
                     (patents_df['KINDDATE'] == "PRIORITY") & (patents_df['KINDCOUNTRY'] == "INVENTORS")
                     & (patents_df['Patents Office & Patents Families'] == "Patent applications to the EPO")]

# Drop unnecessary columns
new_pat = new_pat.drop(columns=["KINDDATE", "IPC", "Patents Office & Patents Families", "KINDCOUNTRY"])

# Rename columns
new_pat = new_pat.rename(columns={"Country": "country", "Value": "patents_number"})

# Convert 'country' column to lowercase
new_pat['country'] = new_pat['country'].str.lower()

# %%
new_pat
# Out:
#              country  patents_number  Time
# 165652       denmark         94.6167  1999
# 165653       denmark         95.6619  2000
# 165654       denmark         85.1917  2001
# 165655       denmark         97.5833  2002
# 165656       denmark        111.1603  2003
# ...              ...             ...   ...
# 170957  south africa         13.8667  2016
# 170958  south africa          8.6667  2017
# 170959  south africa         20.7500  2018
# 170960  south africa         17.3667  2019
# 170961  south africa         11.4167  2020
#
# [1298 rows x 3 columns]

# %%
climate_shocks = pd.read_excel("/content/drive/MyDrive/ELEPHANT/elephant_emdat_custom.xlsx",sheet_name = 0)

# %%
climate_shocks.head()
# Out:
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  1999-9388-DJI       No    nat-cli-dro-dro        Natural    Climatological
# 1  1999-9388-SDN       No    nat-cli-dro-dro        Natural    Climatological
# 2  1999-9388-SOM       No    nat-cli-dro-dro        Natural    Climatological
# 3  2000-0002-AGO       No    nat-hyd-flo-riv        Natural      Hydrological
# 4  2000-0003-BGD       No    nat-met-ext-col        Natural    Meteorological
#
#          Disaster Type Disaster Subtype External IDs Event Name  ISO  ...  \
# 0              Drought          Drought          NaN        NaN  DJI  ...
# 1              Drought          Drought          NaN        NaN  SDN  ...
# 2              Drought          Drought          NaN        NaN  SOM  ...
# 3                Flood   Riverine flood          NaN        NaN  AGO  ...
# 4  Extreme temperature        Cold wave          NaN        NaN  BGD  ...
#
# ...

# %%
print(climate_shocks)
# Out:
#              DisNo. Historic Classification Key Disaster Group  \
# 0     1999-9388-DJI       No    nat-cli-dro-dro        Natural
# 1     1999-9388-SDN       No    nat-cli-dro-dro        Natural
# 2     1999-9388-SOM       No    nat-cli-dro-dro        Natural
# 3     2000-0002-AGO       No    nat-hyd-flo-riv        Natural
# 4     2000-0003-BGD       No    nat-met-ext-col        Natural
# ...             ...      ...                ...            ...
# 9776  2023-0732-HND       No    nat-met-sto-sev        Natural
# 9777  2023-0741-SOM       No    nat-hyd-flo-flo        Natural
# 9778  2023-9167-HND       No    nat-cli-dro-dro        Natural
# 9779  2023-9234-ESP       No    nat-cli-dro-dro        Natural
# 9780  2023-9494-IDN       No    nat-cli-dro-dro        Natural
#
#      Disaster Subgroup        Disaster Type Disaster Subtype  \
# 0       Climatological              Drought          Drought
# 1       Climatological              Drought          Drought
# ...

# %%
climate_awareness = pd.read_excel("/content/drive/MyDrive/ELEPHANT/climate_change_opinion_survey_2022_aggregated.xlsx", sheet_name="climate_worry")

# %%
climate_awareness.head()
# Out:
#         climate_worry    Albania    Algeria     Angola  Argentina    Armenia  \
# 0        Very worried  41.842366  34.574832  54.723818  50.378295  35.560722
# 1    Somewhat worried  39.837751  31.352787  19.441686  34.216395  37.144316
# 2    Not very worried   9.840718  14.549988  14.933694   9.100259  16.890086
# 3  Not at all worried   6.034527  16.932467   7.291281   5.244613  10.260444
# 4             Refused   2.444638   2.589926   3.609521   1.060438   0.144432
#
#    Asian & Pacific Islands  Australia    Austria  Azerbaijan  ...    Tunisia  \
# 0                58.970693  33.640386  37.326637   37.324289  ...  39.181754
# 1                23.108183  39.351043  41.998237   39.202382  ...  32.673791
# 2                11.332094  17.702847  15.661379   11.031423  ...  14.801463
# 3                 5.137799   9.177933   4.641712   11.835333  ...   9.557362
# 4                 1.451231   0.127791   0.372035    0.606572  ...   3.785630
#
# ...

# %%
climate_policies = pd.read_csv("/content/drive/MyDrive/ELEPHANT/EPS_29112023163906367.csv")

# %%
climate_policies.head()
# Out:
#    COU Country           VAR                      Variable   YEA  Year  \
# 0  GRC  Greece  ELV_DIESELSO  Emission limit value sulphur  1990  1990
# 1  GRC  Greece  ELV_DIESELSO  Emission limit value sulphur  1991  1991
# 2  GRC  Greece  ELV_DIESELSO  Emission limit value sulphur  1992  1992
# 3  GRC  Greece  ELV_DIESELSO  Emission limit value sulphur  1993  1993
# 4  GRC  Greece  ELV_DIESELSO  Emission limit value sulphur  1994  1994
#
#    Unit Code  Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0        NaN   NaN               0     Units                    NaN
# 1        NaN   NaN               0     Units                    NaN
# 2        NaN   NaN               0     Units                    NaN
# 3        NaN   NaN               0     Units                    NaN
# 4        NaN   NaN               0     Units                    NaN
#
#    Reference Period  Value  Flag Codes  Flags
# 0               NaN    1.0         NaN    NaN
# ...

# %%
# education.rename(columns = {"Country Name_x":"country"}, inplace=True)
# education.country = education.country.apply(lambda x: x.lower())
# edu_country = list(education.country.unique())
# len(education.country.unique())

# %%
# x = pd.merge(education,df_1,on="country")

# %%
# len(x.country.unique())

# %%
# merged_data = pd.merge(x,new_pat,on="country")

# %%
# len(merged_data.country.unique())

# %%
# #MUST CONVERT OBJECTS TO FLOAT
# merged_data["GDP per capita"] = merged_data["GDP per capita"].str.replace(",",".").astype(np.float32)
# merged_data["SDG Index Score"] = merged_data["SDG Index Score"].str.replace(",",".").astype(np.float16)
# # merged_data["Secondary education"] = merged_data["Secondary education"].str.replace(",",".").astype(np.float16)
# merged_data["Tertiary education"] = merged_data["Tertiary education"].str.replace(",",".").astype(np.float16)

# %%
# fig = plt.gcf()

# # Changing Seaborn Plot size
# fig.set_size_inches(12, 8)
# bar = sns.barplot(data = merged_data, x = "country", y ="patience")
# bar.set_xticklabels(bar.get_xticklabels(), rotation=90)

# %%
# scatter = sns.scatterplot(data = y, x = "patents per capita", y = "patience", hue='cluster', style= 'cluster',)
# scatter.set_xscale("log")

# %%
# y.loc[y["GDP per capita"] > y["GDP per capita"].mean()] = 0
# y.loc[y['altruism'] < altruism_mean, 'Cluster'] = 0
# y.loc[y["Secondary education"] > y["Secondary education"].mean()] = 1

# %%
# low_gdp = y[y["GDP per capita"] <= y["GDP per capita"].mean()]
# low_ed = y[y["Secondary education"] <= y["Secondary education"].mean()]

# %%
# low_gdp.corr()

# %%
# low_edcorr = low_ed.corr()

# heatmap_corr = px.imshow(
#     low_edcorr.values.round(2),         # correlation matrix values, rounded at 2 decimals
#     x=list(low_edcorr.columns),         # label x-axis
#     y=list(low_edcorr.index),           # label y-axis
#     text_auto=True,
#     aspect="auto"
# )
# heatmap_corr.update_xaxes(side="top")

# %%
# x_above = high_gdp[["patience","patents_number"]]
# x_below = low_gdp[["patience","patents_number"]]
# ed_above = high_ed[["patience","patents_number"]]
# ed_below = low_ed[["patience","patents_number"]]

# %%
# print(ed_above.corr())
# print('\n')
# print(ed_below.corr())

# %%
# x_above.corr()

# %%
# x_below.corr()

# %%
#sns.factorplot(x='country', y='patents_number', data=y, aspect = 4)
sns.relplot(x='patience', y='patents_number', data=y, kind='line', hue = 'cluster')
plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-5e331a4ddb5c> in <cell line: 2>()
#       1 #sns.factorplot(x='country', y='patents_number', data=y, aspect = 4)
# ----> 2 sns.relplot(x='patience', y='patents_number', data=y, kind='line', hue = 'cluster')
#       3 plt.xticks(rotation=90)
#
# NameError: name 'y' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x='patience', y='patents_number',data=y)
plt.yscale('log')
#plt.xscale('log')

# %%
sns.regplot(x='patience', y='patents per capita',data=y)
plt.yscale('log')

# %%
#Plot the best fit line for the two subsamples: below/above median rain.


sns.lineplot(x='patience', y='patents_number', data=x_above)
sns.lineplot(x='patience', y='patents_number', data=x_below)
'''plt.yscale('log')
plt.xscale('log')
'''
